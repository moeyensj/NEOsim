# 85926  1685084       401    8.945181 -34.807313  52480.387550  21.4049
# 85927  1685087      1794    9.075592 -47.994437  52480.389103  19.7589
# 85928  1685094       466   25.042086 -48.293492  52480.392286  21.3330
# 85929  1685100      6540   31.699331 -56.624866  52480.394975  21.7958
# 85930  1685102      5350  345.916119 -11.300958  52480.396867  21.6559
# 85931  1685105      3523  350.076498 -14.888349  52480.398241  21.4149
# 85932  1685106      4127  354.041095 -20.444591  52480.398715  21.6113
# 85933  1685107      2162  354.736785 -22.349043  52480.399172  21.3424
# 85934  1685111       400  355.926102 -30.073044  52480.400991  20.6517
# 85935  1685114      2179  350.154804 -27.946381  52480.402347  21.2803
# 85936  1685116       400  355.925400 -30.073291  52480.403276  20.6513
# 85937  1685128      7515  351.244855 -41.222289  52480.408753  21.8425
# 85938  1685130      7515  351.234396 -41.222589  52480.409675  21.8531
# 85939  1685132       212    0.545087 -38.677174  52480.410840  18.7334
# 85940  1685135       401    8.940526 -34.811951  52480.412225  21.4043
# 85941  1685138      1794    9.104723 -47.981697  52480.413794  19.7610
# 85942  1685142      7408   26.265315 -54.633195  52480.415685  21.9673
# 85943  1685143      7408   26.266846 -54.634358  52480.416133  21.9791
# 85944  1685145       466   24.927073 -48.248013  52480.417030  21.3425
# 85945  1685155      6540   31.679428 -56.634501  52480.421559  21.7969
#
#              snr
# diaId
# 0       14.68430
# 1       15.08580
# 2      100.80400
# 3       15.71120
# 4       15.08180
# 5       26.04840
# 6       15.15950
# 7       54.38470
# 8        5.01000
# 9      559.64900
# 10      54.64740
# 11      19.93470
# 12      82.51740
# 13     236.74800
# 14     236.41000
# 15       5.01000
# 16     117.66800
# 17      19.09700
# 18      17.93300
# 19      12.84870
# 20      17.95180
# 21     237.67600
# 22     238.61800
# 23      18.13180
# 24      85.30210
# 25      71.16900
# 26      23.62490
# 27      24.31410
# 28       5.01000
# 29      18.74200
# ...          ...
# 85916   23.36480
# 85917    5.84211
# 85918   72.46390
# 85919    6.76110
# 85920    9.37943
# 85921   20.83410
# 85922    9.52338
# 85923   20.37360
# 85924    5.18050
# 85925  124.30300
# 85926   11.01360
# 85927   56.42870
# 85928   12.64090
# 85929    7.04526
# 85930    5.69244
# 85931    7.56957
# 85932    6.53613
# 85933    9.13899
# 85934   20.48350
# 85935    9.20486
# 85936   19.93950
# 85937    5.11068
# 85938    5.21078
# 85939  123.96800
# 85940   11.12750
# 85941   56.96120
# 85942    6.07496
# 85943    6.18118
# 85944   13.09950
# 85945    7.41903
#
# [85946 rows x 7 columns]

# %%
MopsPlotter.plotDataframe(dets_df)

# %%
nightly = dataDrive + "neosimData/jpl/nightly/"

! rm -rf {nightly}
! mkdir {nightly}

# %%
call = ["python", os.getenv("MOPS_DIR") + "/bin/splitByNight.py", "-n", nightly, dataDrive + dataLocation]
subprocess.call(call);

# %%
parameters = MopsParameters(velocity_max="2.0", detection_error_threshold="0.0")
tracker = MopsTracker(runLocation)
tracker.getDetections(nightly)
# Out:
# ------- MOPS Parameters --------
# Current Parameter Values:
#
# ---- findTracklets ----
# 	Maximum velocity:                         2.0
# 	Minimum velocity:                         0.0
# ---- collapseTracklets ----
# 	Right Ascension tolerance:                0.002
# 	Declination tolerance:                    0.002
# 	Angular tolerance:                        5
# 	Velocity tolerance:                       0.05
# 	Method:                                   greedy
# 	Use RMS filter:                           True
# 	Maximum RMS:                              0.001
# ---- purifyTracklets ----
# 	Maximum RMS:                              0.001
# ---- removeSubsets (tracklets) ----
# 	Remove subsets:                           False
# 	Keep only longest:                        False
# ---- makeLinkTrackletsInput_byNight.py ----
# 	Window size:                              15
# ---- linkTracklets ----
# 	Detection error threshold:                0.0
# 	Maximum right ascension acceleration:     0.02
# 	Maximum declination acceleration:         0.02
# 	Latest first endpoint:                    None
# 	Earliest last endpoint:                   None
# 	Minimum nights:                           3
# 	Minimum detections:                       6
# 	Output buffer size:                       1000
# 	Maximum leaf node size:                   None
# ---- removeSubsets (tracks) ----
# 	Remove subsets:                           True
# 	Keep only longest:                        True
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     False
# 	idsToIndices.py:                   False
# 	collapseTracklets:                 False
# 	purifyTracklets:                   False
# 	removeSubsets (tracklets):         False
# 	indicesToIds.py:                   False
# 	makeLinkTrackletsInputByNight.py:  False
# 	linkTracklets:                     False
# 	removeSubsets (tracks):            False
#
# Found 72 detection files in /Volumes/DataCenter/neosimData/jpl/nightly/.

# %%
parameters, tracker = runMops.runMops(parameters, tracker, overwrite=True, processes=4)
# Out:
# ------- Run MOPS -------
# Running LSST's Moving Object Pipeline
#
# Overwrite triggered: clearing tracker...
#
# Found 72 detection files in /Volumes/DataCenter/neosimData/jpl/nightly/.
#
# Overwrite triggered: deleting existing directory...
#
# Saving parameters to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/parameters.yaml
#
# ------- Run MOPS -------
# Running findTracklets...
# Completed running findTracklets.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml
#
# ------- Run MOPS -------
# Running idsToIndices.py...
# Completed running idsToIndices.py.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml
#
# ------- Run MOPS -------
# Running collapseTracklets...
# Completed running collapseTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml
#
# ------- Run MOPS -------
# Running purifyTracklets...
# Completed running purifyTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml
#
# ------- Run MOPS -------
# Running makeLinkTrackletsInput_byNight.py...
# Completed running makeLinkTrackletsInput_byNight.py.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml
#
# ------- Run MOPS -------
# Running linkTracklets...
# Multiprocessing Enabled!
# Using 4 CPUs in parallel.
# Completed running linkTracklets.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     True
# 	idsToIndices.py:                   True
# 	collapseTracklets:                 True
# 	purifyTracklets:                   True
# 	removeSubsets (tracklets):         True
# 	indicesToIds.py:                   True
# 	makeLinkTrackletsInputByNight.py:  True
# 	linkTracklets:                     True
# 	removeSubsets (tracks):            True
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml

# %%
parameters = MopsParameters.fromYaml(runLocation + "parameters.yaml")
tracker = MopsTracker.fromYaml(runLocation + "tracker.yaml")
# Out:
# Loading parameters from /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/parameters.yaml
# Loading tracker from /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml

# %%
results, df = MopsAnalysis.analyze(parameters, tracker, fullDetFile=dataDrive + dataLocation, overwrite=True)
# Out:
# Overwrite triggered: deleting existing results directory...
#
# Initializing new results object...
# Creating DiaSources table...
# Creating AllObjects table...
# Creating FoundObjects view...
# Creating MissedObjects view...
# Creating AllTracklets table...
# Creating TrackletMembers table...
# Creating Tracklets view...
# Creating CollapsedTracklets view...
# Creating PurifiedTracklets view...
# Creating FinalTracklets view...
#
# Reading full detections file into dataframe...
# Counting findable objects as tracklets...
# Counting findable objects as tracks...
# Building objects dataframe...
# Updating objects dataframe...
# Reading full detections file into database...
#
# Starting tracklet analysis for 72 nights...
#
# Starting tracklet analysis for night 52391 at Wed Mar 30 10:59:54 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/
2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52415.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 666 tracklets into 122 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 0 tracklets and created 0 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52415 at Wed Mar 30 11:02:26 2016
#
# Starting tracklet analysis for night 52416 at Wed Mar 30 11:02:26 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52416.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# ...
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 0 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52465 - 52480) at Wed Mar 30 11:11:06 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52467 - 52480) at Wed Mar 30 11:11:06 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52467-52480.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 0 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52467 - 52480) at Wed Mar 30 11:11:08 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52468 - 52480) at Wed Mar 30 11:11:08 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52468-52480.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 0 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52468 - 52480) at Wed Mar 30 11:11:11 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52469 - 52480) at Wed Mar 30 11:11:11 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52469-52480.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 0 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52469 - 52480) at Wed Mar 30 11:11:13 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52470 - 52480) at Wed Mar 30 11:11:13 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52470-52480.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 0 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52470 - 52480) at Wed Mar 30 11:11:15 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52471 - 52480) at Wed Mar 30 11:11:15 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52471-52480.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 0 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52471 - 52480) at Wed Mar 30 11:11:16 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52472 - 52480) at Wed Mar 30 11:11:16 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52472-52480.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 0 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52472 - 52480) at Wed Mar 30 11:11:18 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52473 - 52480) at Wed Mar 30 11:11:18 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52473-52480.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 0 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52473 - 52480) at Wed Mar 30 11:11:20 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52476 - 52480) at Wed Mar 30 11:11:20 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52476-52480.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 0 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52476 - 52480) at Wed Mar 30 11:11:21 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52477 - 52480) at Wed Mar 30 11:11:21 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52477-52480.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 0 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52477 - 52480) at Wed Mar 30 11:11:22 2016
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/tracker.yaml
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/tracker.yaml
#
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results.yaml
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/results.yaml

# %%
results = MopsResults.fromYaml(runLocation + "results.yaml")
# Out:
# Loading results from /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results.yaml

# %%
import MopsDatabase
import MopsPlotter

# %%
con = sql.connect(tracker.mainDatabase)
window_dbs = MopsDatabase.attachDatabases(con, tracker.windowDatabases)
# Out:
# Warning: Cannot attach more than 10 databases...
# Proceeding with the first 10 databases...
# Attaching /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52391-52406.db to con as db0...
# Attaching /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52392-52406.db to con as db1...
# Attaching /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52393-52408.db to con as db2...
# Attaching /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52394-52408.db to con as db3...
# Attaching /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52395-52410.db to con as db4...
# Attaching /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52396-52411.db to con as db5...
# Attaching /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52397-52412.db to con as db6...
# Attaching /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52398-52413.db to con as db7...
# Attaching /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52399-52413.db to con as db8...
# Attaching /Volumes/DataCenter/neosimData/jpl_2016_03_25_DetErrorThresh0/results/52400-52415.db to con as db9...

# %%
missed_objects = pd.read_sql("""SELECT objectId FROM AllObjects
                                    WHERE findableAsTrack = 1
                                    AND numTrueTracks = 0""", con)["objectId"].values
found_objects = pd.read_sql("""SELECT objectId FROM AllObjects
                                    WHERE findableAsTrack = 1
                                    AND numTrueTracks >= 1""", con)["objectId"].values

missed_objects_detections = MopsDatabase.findDetectionsWithObjectIds(con, missed_objects)
found_objects_detections = MopsDatabase.findDetectionsWithObjectIds(con, found_objects)

fig, ax = plt.subplots(1,2)
fig.set_size_inches(14,7)

ax[0].scatter(found_objects_detections["ra"], found_objects_detections["dec"], c="b", label="%s Found objects" % len(found_objects))
ax[1].scatter(missed_objects_detections["ra"], missed_objects_detections["dec"], c="r",  label="%s Missed objects" % len(missed_objects))

for a in ax:
    a.legend()
    a.set_xlabel("RA", size=16);
    a.set_ylabel("DEC", size=16);   
    
ax[0].set_title("Found Objects and Their Detections")
ax[1].set_title("Missed Objects and Their Detections")

hist, bin_edges = np.histogram(found_objects_detections["mag"].values, bins=np.linspace(12,26,15))
hist2, bins = np.histogram(missed_objects_detections["mag"].values, bins=bin_edges)
width = 0.4

fig, ax = plt.subplots(1,1)
fig.set_size_inches(10,7)
ax.bar(bin_edges[1:], hist/float(len(found_objects_detections))*100.0, width, label="Found")
ax.bar(bin_edges[1:] + width, hist2/float(len(missed_objects_detections))*100.0, width, color="r", label="Missed")
#ax.set_xticks(bin_edges[1:]);
ax.legend(loc="upper left");
ax.grid();
ax.set_title("MAG Distribution as Percent of Detections");
ax.set_xlabel("MAG");
ax.set_ylabel("% Freq");

hist, bin_edges = np.histogram(found_objects_detections["snr"].values, bins=np.linspace(0,60,20))
hist2, bins = np.histogram(missed_objects_detections["snr"].values, bins=bin_edges)
width = 0.75

fig, ax = plt.subplots(1,1)
fig.set_size_inches(10,7)
ax.bar(bin_edges[1:], hist/float(len(found_objects_detections))*100.0, width, label="Found")
ax.bar(bin_edges[1:] + width, hist2/float(len(missed_objects_detections))*100.0, width, color="r", label="Missed")
#ax.set_xticks(bin_edges[1:]);
ax.legend(loc="upper right");
ax.grid();
ax.set_title("SNR Distribution as Percent of Detections");
ax.set_xlabel("SNR");
ax.set_ylabel("% Freq");

missed_objects_velocities = pd.read_sql("""SELECT AllTracklets.trackletId, DiaSources.objectId, trackletMembers.diaId, ra, dec, velocity, rms, findableAsTrack, numTrueTracks FROM AllTracklets
                                             JOIN TrackletMembers ON
                                                AllTracklets.trackletId = TrackletMembers.trackletId
                                            JOIN DiaSources ON
                                                TrackletMembers.diaId = DiaSources.diaId
                                            JOIN AllObjects ON
                                                DiaSources.objectId = AllObjects.objectId
                                            WHERE findableAsTrack = 1
                                            AND numTrueTracks = 0;
                                            """, con)
found_objects_velocities = pd.read_sql("""SELECT AllTracklets.trackletId, DiaSources.objectId, trackletMembers.diaId, ra, dec, velocity, rms, findableAsTrack, numTrueTracks FROM AllTracklets
                                             JOIN TrackletMembers ON
                                                AllTracklets.trackletId = TrackletMembers.trackletId
                                            JOIN DiaSources ON
                                                TrackletMembers.diaId = DiaSources.diaId
                                            JOIN AllObjects ON
                                                DiaSources.objectId = AllObjects.objectId
                                            WHERE findableAsTrack = 1
                                            AND numTrueTracks >= 1 ;
                                            """, con)

hist, bin_edges = np.histogram(found_objects_velocities["velocity"].values, bins=np.linspace(0,2.5,15))
hist2, bins = np.histogram(missed_objects_velocities["velocity"].values, bins=bin_edges)
width = 0.05

fig, ax = plt.subplots(1,1)
fig.set_size_inches(10,7)
ax.bar(bin_edges[1:], hist, width, label="Found")
ax.bar(bin_edges[1:] + width, hist2, width, color="r", label="Missed")
ax.legend(loc="upper right");
ax.grid();
ax.set_title("Velocity Distribution");
ax.set_xlabel("Velocity");
ax.set_ylabel("Freq");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-d951ef73dc93> in <module>()
#      12 fig.set_size_inches(14,7)
#      13
# ---> 14 ax[0].scatter(found_objects_detections["ra"], found_objects_detections["dec"], c="b", label="%s Found objects" % len(found_objects))
#      15 ax[1].scatter(missed_objects_detections["ra"], missed_objects_detections["dec"], c="r",  label="%s Missed objects" % len(missed_objects))
#      16
#
# /Users/joachim/anaconda/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/joachim/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3863
#    3864         # c will be unchanged unless it is the same length as x:
# -> 3865         x, y, s, c = cbook.delete_masked_points(x, y, s, c)
#    3866
#    3867         scales = s   # Renamed for readability below.
#
# /Users/joachim/anaconda/lib/python2.7/site-packages/matplotlib/cbook.pyc in delete_masked_points(*args)
#    1835         return ()
#    1836     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1837         raise ValueError("First argument must be a sequence")
#    1838     nrecs = len(args[0])
#    1839     margs = []
#
# ValueError: First argument must be a sequence
