# 85925  1685081       212    0.525186 -38.673380  52480.386073  18.7376
# 85926  1685084       401    8.945181 -34.807313  52480.387550  21.4049
# 85927  1685087      1794    9.075592 -47.994437  52480.389103  19.7589
# 85928  1685094       466   25.042086 -48.293492  52480.392286  21.3330
# 85929  1685100      6540   31.699331 -56.624866  52480.394975  21.7958
# 85930  1685102      5350  345.916119 -11.300958  52480.396867  21.6559
# 85931  1685105      3523  350.076498 -14.888349  52480.398241  21.4149
# 85932  1685106      4127  354.041095 -20.444591  52480.398715  21.6113
# 85933  1685107      2162  354.736785 -22.349043  52480.399172  21.3424
# 85934  1685111       400  355.926102 -30.073044  52480.400991  20.6517
# 85935  1685114      2179  350.154804 -27.946381  52480.402347  21.2803
# 85936  1685116       400  355.925400 -30.073291  52480.403276  20.6513
# 85937  1685128      7515  351.244855 -41.222289  52480.408753  21.8425
# 85938  1685130      7515  351.234396 -41.222589  52480.409675  21.8531
# 85939  1685132       212    0.545087 -38.677174  52480.410840  18.7334
# 85940  1685135       401    8.940526 -34.811951  52480.412225  21.4043
# 85941  1685138      1794    9.104723 -47.981697  52480.413794  19.7610
# 85942  1685142      7408   26.265315 -54.633195  52480.415685  21.9673
# 85943  1685143      7408   26.266846 -54.634358  52480.416133  21.9791
# 85944  1685145       466   24.927073 -48.248013  52480.417030  21.3425
# 85945  1685155      6540   31.679428 -56.634501  52480.421559  21.7969
#
#              snr
# diaId
# 0       14.68430
# 1       15.08580
# 2      100.80400
# 3       15.71120
# 4       15.08180
# 5       26.04840
# 6       15.15950
# 7       54.38470
# 8        5.01000
# 9      559.64900
# 10      54.64740
# 11      19.93470
# 12      82.51740
# 13     236.74800
# 14     236.41000
# 15       5.01000
# 16     117.66800
# 17      19.09700
# 18      17.93300
# 19      12.84870
# 20      17.95180
# 21     237.67600
# 22     238.61800
# 23      18.13180
# 24      85.30210
# 25      71.16900
# 26      23.62490
# 27      24.31410
# 28       5.01000
# 29      18.74200
# ...          ...
# 85916   23.36480
# 85917    5.84211
# 85918   72.46390
# 85919    6.76110
# 85920    9.37943
# 85921   20.83410
# 85922    9.52338
# 85923   20.37360
# 85924    5.18050
# 85925  124.30300
# 85926   11.01360
# 85927   56.42870
# 85928   12.64090
# 85929    7.04526
# 85930    5.69244
# 85931    7.56957
# 85932    6.53613
# 85933    9.13899
# 85934   20.48350
# 85935    9.20486
# 85936   19.93950
# 85937    5.11068
# 85938    5.21078
# 85939  123.96800
# 85940   11.12750
# 85941   56.96120
# 85942    6.07496
# 85943    6.18118
# 85944   13.09950
# 85945    7.41903
#
# [85946 rows x 7 columns]

# %%
MopsPlotter.plotDataframe(dets_df)

# %%
nightly = dataDrive + "neosimData/jpl/nightly/"

! rm -rf {nightly}
! mkdir {nightly}

# %%
call = ["python", os.getenv("MOPS_DIR") + "/bin/splitByNight.py", "-n", nightly, dataDrive + dataLocation]
subprocess.call(call);

# %%
parameters = MopsParameters(velocity_max="2.0", ra_tolerance="0.5", dec_tolerance="0.5", velocity_tolerance="0.5", use_rms_filter="False")
tracker = MopsTracker(runLocation)
tracker.getDetections(nightly)
# Out:
# ------- MOPS Parameters --------
# Current Parameter Values:
#
# ---- findTracklets ----
# 	Maximum velocity:                         2.0
# 	Minimum velocity:                         0.0
# ---- collapseTracklets ----
# 	Right Ascension tolerance:                0.5
# 	Declination tolerance:                    0.5
# 	Angular tolerance:                        5
# 	Velocity tolerance:                       0.5
# 	Method:                                   greedy
# 	Use RMS filter:                           False
# 	Maximum RMS:                              0.001
# ---- purifyTracklets ----
# 	Maximum RMS:                              0.001
# ---- removeSubsets (tracklets) ----
# 	Remove subsets:                           False
# 	Keep only longest:                        False
# ---- makeLinkTrackletsInput_byNight.py ----
# 	Window size:                              15
# ---- linkTracklets ----
# 	Detection error threshold:                0.0004
# 	Maximum right ascension acceleration:     0.02
# 	Maximum declination acceleration:         0.02
# 	Latest first endpoint:                    None
# 	Earliest last endpoint:                   None
# 	Minimum nights:                           3
# 	Minimum detections:                       6
# 	Output buffer size:                       1000
# 	Maximum leaf node size:                   None
# ---- removeSubsets (tracks) ----
# 	Remove subsets:                           True
# 	Keep only longest:                        True
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     False
# 	idsToIndices.py:                   False
# 	collapseTracklets:                 False
# 	purifyTracklets:                   False
# 	removeSubsets (tracklets):         False
# 	indicesToIds.py:                   False
# 	makeLinkTrackletsInputByNight.py:  False
# 	linkTracklets:                     False
# 	removeSubsets (tracks):            False
#
# Found 72 detection files in /Volumes/DataCenter/neosimData/jpl/nightly/.

# %%
parameters, tracker = runMops.runMops(parameters, tracker, overwrite=True)
# Out:
# ------- Run MOPS -------
# Running LSST's Moving Object Pipeline
#
# Overwrite triggered: clearing tracker...
#
# Found 72 detection files in /Volumes/DataCenter/neosimData/jpl/nightly/.
#
# Overwrite triggered: deleting existing directory...
#
# Saving parameters to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/parameters.yaml
#
# ------- Run MOPS -------
# Running findTracklets...
# Completed running findTracklets.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml
#
# ------- Run MOPS -------
# Running idsToIndices.py...
# Completed running idsToIndices.py.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml
#
# ------- Run MOPS -------
# Running collapseTracklets...
# Completed running collapseTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml
#
# ------- Run MOPS -------
# Running purifyTracklets...
# Completed running purifyTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml
#
# ------- Run MOPS -------
# Running makeLinkTrackletsInput_byNight.py...
# Completed running makeLinkTrackletsInput_byNight.py.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml
#
# ------- Run MOPS -------
# Running linkTracklets...
# Multiprocessing Enabled!
# Using 8 CPUs in parallel.
# Completed running linkTracklets.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     True
# 	idsToIndices.py:                   True
# 	collapseTracklets:                 True
# 	purifyTracklets:                   True
# 	removeSubsets (tracklets):         True
# 	indicesToIds.py:                   True
# 	makeLinkTrackletsInputByNight.py:  True
# 	linkTracklets:                     True
# 	removeSubsets (tracks):            True
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml

# %%
parameters = MopsParameters.fromYaml(runLocation + "parameters.yaml")
tracker = MopsTracker.fromYaml(runLocation + "tracker.yaml")
# Out:
# Loading parameters from /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/parameters.yaml
# Loading tracker from /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml

# %%
results, df = MopsAnalysis.analyze(parameters, tracker, fullDetFile=dataDrive + dataLocation, overwrite=True)
# Out:
# Initializing new results object...
# Creating DiaSources table...
# Creating AllObjects table...
# Creating FoundObjects view...
# Creating MissedObjects view...
# Creating AllTracklets table...
# Creating TrackletMembers table...
# Creating Tracklets view...
# Creating CollapsedTracklets view...
# Creating PurifiedTracklets view...
# Creating FinalTracklets view...
#
# Reading full detections file into dataframe...
# Counting findable objects as tracklets...
# Counting findable objects as tracks...
# Building objects dataframe...
# Updating objects dataframe...
# Reading full detections file into database...
#
# Starting tracklet analysis for 72 nights...
#
# Starting tracklet analysis for night 52391 at Tue Mar 29 11:24:00 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52391.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 36 tracklets into 12 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 0 tracklets and created 0 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52391 at Tue Mar 29 11:24:02 2016
#
# Starting tracklet analysis for night 52392 at Tue Mar 29 11:24:02 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52392.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 233 tracklets into 47 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 0 tracklets and created 0 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52392 at Tue Mar 29 11:24:05 2016
#
# Starting tracklet analysis for night 52393 at Tue Mar 29 11:24:05 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52393.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 302 tracklets into 66 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 0 tracklets and created 0 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52393 at Tue Mar 29 11:24:08 2016
#
# Starting tracklet analysis for night 52394 at Tue Mar 29 11:24:08 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52394.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 352 tracklets into 63 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 0 tracklets and created 0 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52394 at Tue Mar 29 11:24:11 2016
#
# Starting tracklet analysis for night 52395 at Tue Mar 29 11:24:11 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52395.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 161 tracklets into 32 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 0 tracklets and created 0 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52395 at Tue Mar 29 11:24:14 2016
#
# Starting tracklet analysis for night 52396 at Tue Mar 29 11:24:14 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52396.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 913 tracklets into 190 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 0 tracklets and created 0 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52396 at Tue Mar 29 11:24:23 2016
#
# Starting tracklet analysis for night 52397 at Tue Mar 29 11:24:23 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52397.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 1840 tracklets into 241 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# Unexpected wierdness, diasource had angular distance of 0.119055 from best-fit curve prediction
# Predicted RA, Dec were  241.549795817 -14.6909089638
# observed RA, Dec were  241.66220038 -14.739433633
# all RAs were  [241.675734433, 241.66220038, 241.349834582, 241.34972453700001, 241.34497883400002, 241.344867569, 241.343871455, 241.34054808799999]
# all decs were  [-14.739237153199999, -14.739433632999999, -14.6105016061, -14.6104992945, -14.6103909103, -14.610388164000002, -14.6103631555, -14.610274211099998]
# Unexpected wierdness, diasource had angular distance of 0.119301 from best-fit curve prediction
# Predicted RA, Dec were  241.470275746 -14.656520858
# observed RA, Dec were  241.356464122 -14.6106243303
# all RAs were  [241.675734433, 241.35646412200001, 241.64436397700001, 241.34972453700001, 241.34497883400002, 241.344867569, 241.343871455, 241.61947168700001]
# all decs were  [-14.739237153199999, -14.6106243303, -14.7396710114, -14.6104992945, -14.6103909103, -14.610388164000002, -14.6103631555, -14.739960161500001]
# Unexpected wierdness, diasource had angular distance of 0.280464 from best-fit curve prediction
# Predicted RA, Dec were  241.380478353 -14.62349198
# observed RA, Dec were  241.644363977 -14.7396710114
# all RAs were  [241.675734433, 241.35646412200001, 241.64436397700001, 241.34972453700001, 241.34497883400002, 241.344867569, 241.343871455, 241.61947168700001]
# all decs were  [-14.739237153199999, -14.6106243303, -14.7396710114, -14.6104992945, -14.6103909103, -14.610388164000002, -14.6103631555, -14.739960161500001]
# Unexpected wierdness, diasource had angular distance of 0.100968 from best-fit curve prediction
# Predicted RA, Dec were  241.437972529 -14.6540047837
# observed RA, Dec were  241.343871455 -14.6103631555
collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# Unexpected wierdness, diasource had angular distance of 0.163142 from best-fit curve prediction
# Predicted RA, Dec were  304.454285732 -37.4577109009
# observed RA, Dec were  304.346189681 -37.3190061819
# all RAs were  [304.636384136, 304.63646777299999, 304.63884769800001, 304.63942617800001, 304.346189681, 304.35127346400003]
# all decs were  [-37.699091467199999, -37.699110382900002, -37.699646308699997, -37.699775817199999, -37.319006181900001, -37.3203945299]
# Unexpected wierdness, diasource had angular distance of 0.244907 from best-fit curve prediction
# Predicted RA, Dec were  304.473182479 -37.4911059364
# observed RA, Dec were  304.636384136 -37.6990914672
# all RAs were  [304.636384136, 304.33535257799997, 304.63884769800001, 304.34066250900003, 304.642479799, 304.35127346400003]
# all decs were  [-37.699091467199999, -37.316035810700001, -37.699646308699997, -37.317492745199999, -37.700453550900001, -37.3203945299]
# Unexpected wierdness, diasource had angular distance of 0.211448 from best-fit curve prediction
# Predicted RA, Dec were  304.476520477 -37.4953000371
# observed RA, Dec were  304.335352578 -37.3160358107
# all RAs were  [304.636384136, 304.33535257799997, 304.63884769800001, 304.34066250900003, 304.642479799, 304.35127346400003]
# all decs were  [-37.699091467199999, -37.316035810700001, -37.699646308699997, -37.317492745199999, -37.700453550900001, -37.3203945299]
# Unexpected wierdness, diasource had angular distance of 0.148497 from best-fit curve prediction
# Predicted RA, Dec were  304.539758451 -37.5735753372
# observed RA, Dec were  304.638847698 -37.6996463087
# all RAs were  [304.636384136, 304.33535257799997, 304.63884769800001, 304.34066250900003, 304.642479799, 304.35127346400003]
# all decs were  [-37.699091467199999, -37.316035810700001, -37.699646308699997, -37.317492745199999, -37.700453550900001, -37.3203945299]
# Unexpected wierdness, diasource had angular distance of 0.309306 from best-fit curve prediction
# Predicted RA, Dec were  304.545754955 -37.5804738831
# observed RA, Dec were  304.340662509 -37.3174927452
# all RAs were  [304.636384136, 304.33535257799997, 304.63884769800001, 304.34066250900003, 304.642479799, 304.35127346400003]
# all decs were  [-37.699091467199999, -37.316035810700001, -37.699646308699997, -37.317492745199999, -37.700453550900001, -37.3203945299]
# Unexpected wierdness, diasource had angular distance of 0.192355 from best-fit curve prediction
# Predicted RA, Dec were  304.515324772 -37.5365751882
# observed RA, Dec were  304.642479799 -37.7004535509
# all RAs were  [304.636384136, 304.33535257799997, 304.63884769800001, 304.34066250900003, 304.642479799, 304.35127346400003]
# all decs were  [-37.699091467199999, -37.316035810700001, -37.699646308699997, -37.317492745199999, -37.700453550900001, -37.3203945299]
# RMS error was 0.209639
# Unexpected wierdness, diasource had angular distance of 0.169566 from best-fit curve prediction
# Predicted RA, Dec were  304.52295051 -37.5552811609
# observed RA, Dec were  304.636384136 -37.6990914672
# all RAs were  [304.636384136, 304.33535257799997, 304.63884769800001, 304.34066250900003, 304.346189681, 304.64526759099999]
# all decs were  [-37.699091467199999, -37.316035810700001, -37.699646308699997, -37.317492745199999, -37.319006181900001, -37.701062065100004]
# Unexpected wierdness, diasource had angular distance of 0.274714 from best-fit curve prediction
# Predicted RA, Dec were  304.518315291 -37.5491880028
# observed RA, Dec were  304.335352578 -37.3160358107
# all RAs were  [304.636384136, 304.33535257799997, 304.63884769800001, 304.34066250900003, 304.346189681, 304.64526759099999]
# all decs were  [-37.699091467199999, -37.316035810700001, -37.699646308699997, -37.317492745199999, -37.319006181900001, -37.701062065100004]
# Unexpected wierdness, diasource had angular distance of 0.317145 from best-fit curve prediction
# Predicted RA, Dec were  304.428371531 -37.4299309024
# observed RA, Dec were  304.638847698 -37.6996463087
# all RAs were  [304.636384136, 304.33535257799997, 304.63884769800001, 304.34066250900003, 304.346189681, 304.64526759099999]
# all decs were  [-37.699091467199999, -37.316035810700001, -37.699646308699997, -37.317492745199999, -37.319006181900001, -37.701062065100004]
# Unexpected wierdness, diasource had angular distance of 0.117275 from best-fit curve prediction
# Predicted RA, Dec were  304.418898185 -37.4169273124
# observed RA, Dec were  304.340662509 -37.3174927452
# all RAs were  [304.636384136, 304.33535257799997, 304.63884769800001, 304.34066250900003, 304.346189681, 304.64526759099999]
# all decs were  [-37.699091467199999, -37.316035810700001, -37.699646308699997, -37.317492745199999, -37.319006181900001, -37.701062065100004]
# Unexpected wierdness, diasource had angular distance of 0.158715 from best-fit curve prediction
# Predicted RA, Dec were  304.450942511 -37.4541469215
# observed RA, Dec were  304.346189681 -37.3190061819
# all RAs were  [304.636384136, 304.33535257799997, 304.63884769800001, 304.34066250900003, 304.346189681, 304.64526759099999]
# all decs were  [-37.699091467199999, -37.316035810700001, -37.699646308699997, -37.317492745199999, -37.319006181900001, -37.701062065100004]
# RMS error was 0.203220
# Unexpected wierdness, diasource had angular distance of 0.352435 from best-fit curve prediction
# Predicted RA, Dec were  335.114690201 -24.6292949351
# observed RA, Dec were  335.395990416 -24.8720933071
# all RAs were  [335.39599041599996, 334.89603327399999, 335.41283678599996, 334.90728794299997, 334.90782560099996]
# all decs were  [-24.872093307100002, -24.438919856799998, -24.867427610300002, -24.435161527800002, -24.434981704499997]
# Unexpected wierdness, diasource had angular distance of 0.369836 from best-fit curve prediction
# Predicted RA, Dec were  335.190994305 -24.6935071319
# observed RA, Dec were  334.896033274 -24.4389198568
# all RAs were  [335.39599041599996, 334.89603327399999, 335.41283678599996, 334.90728794299997, 334.90782560099996]
# all decs were  [-24.872093307100002, -24.438919856799998, -24.867427610300002, -24.435161527800002, -24.434981704499997]
# Unexpected wierdness, diasource had angular distance of 0.293606 from best-fit curve prediction
# Predicted RA, Dec were  335.177754762 -24.6658342997
# observed RA, Dec were  335.412836786 -24.8674276103
# all RAs were  [335.39599041599996, 334.89603327399999, 335.41283678599996, 334.90728794299997, 334.90782560099996]
# all decs were  [-24.872093307100002, -24.438919856799998, -24.867427610300002, -24.435161527800002, -24.434981704499997]
# Unexpected wierdness, diasource had angular distance of 0.241370 from best-fit curve prediction
# Predicted RA, Dec were  335.100803095 -24.6002685898
# observed RA, Dec were  334.907287943 -24.4351615278
# all RAs were  [335.39599041599996, 334.89603327399999, 335.41283678599996, 334.90728794299997, 334.90782560099996]
# all decs were  [-24.872093307100002, -24.438919856799998, -24.867427610300002, -24.435161527800002, -24.434981704499997]
# RMS error was 0.285205
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 4 tracklets and created 4 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52405 at Tue Mar 29 11:25:47 2016
#
# Starting tracklet analysis for night 52406 at Tue Mar 29 11:25:47 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52406.results
# - Checking file sizes...
# - Reading input detections...
# ...
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 249 tracklets into 55 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 0 tracklets and created 0 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52476 at Tue Mar 29 11:31:30 2016
#
# Starting tracklet analysis for night 52477 at Tue Mar 29 11:31:30 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52477.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 87 tracklets into 19 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 0 tracklets and created 0 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52477 at Tue Mar 29 11:31:32 2016
#
# Starting tracklet analysis for night 52478 at Tue Mar 29 11:31:32 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52478.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 71 tracklets into 21 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 0 tracklets and created 0 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52478 at Tue Mar 29 11:31:34 2016
#
# Starting tracklet analysis for night 52480 at Tue Mar 29 11:31:34 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52480.results
# - Checking file sizes...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing tracklet file...
# - Building dataframes...
# - Building tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing collapsed tracklets...
# collapseTracklets merged 230 tracklets into 39 collinear tracklets...
# - Updating dataframe properties...
# - Building collapsed tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing purified tracklets...
# purifiedTracklets removed detections from 1 tracklets and created 1 tracklets...
# - Updating dataframe properties...
# - Building purified tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracklets...
# removeSubsets removed 0 tracklets...
# - Updating dataframe properties...
# - Building final tracklets...
# - Appended new tracklets to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackletMembers tables...
# Updating AllTracklets tables...
#
# Finished tracklet analysis for night 52480 at Tue Mar 29 11:31:37 2016
#
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/tracker.yaml
# Saving tracker to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/tracker.yaml
#
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results.yaml
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
#
# Starting track analysis for 70 windows...
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52391 - 52406) at Tue Mar 29 11:31:38 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52391-52406.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 352 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52391 - 52406) at Tue Mar 29 11:31:52 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52392 - 52406) at Tue Mar 29 11:31:52 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52392-52406.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 346 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52392 - 52406) at Tue Mar 29 11:32:06 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52393 - 52408) at Tue Mar 29 11:32:06 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52393-52408.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 419 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52393 - 52408) at Tue Mar 29 11:32:22 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52394 - 52408) at Tue Mar 29 11:32:22 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52394-52408.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Writing detection file summary to outfile...
#
# Analyzing track file...
# - Building dataframes...
# - Building tracks...
# - Appended new tracks to dataframes...
# - Counting subset tracks...
# - Updating AllTracks dataframe...
# - Counting missed objects...
# - Calculating performance...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Analyzing final tracks...
# removeSubsets removed 401 tracks...
# - Updating dataframe properties...
# - Building final tracks...
# - Appended new tracks to dataframes...
# - Updating results object...
# Saving results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/results.yaml
# - Updating objects dataframe...
# - Writing results to outfile...
#
# Converting dataframes to sqlite tables...
# Updating TrackMembers table...
# Updating AllTracks table...
#
# Finished track analysis for window (nights: 52394 - 52408) at Tue Mar 29 11:32:38 2016
#
# Creating AllTracks table...
# Creating TrackMembers table...
# Creating Tracks view...
# Creating FinalTracks view...
#
# Starting track analysis for window (nights: 52395 - 52410) at Tue Mar 29 11:32:38 2016
#
# - Writing results to /Volumes/DataCenter/neosimData/jpl_2016_03_28_generousCollapsePurifyRemove/results/52395-52410.results
# - Checking file sizes...
# - Counting number of input tracks...
# - Reading input detections...
# - Counting findable objects...

# %%
results = MopsResults.fromYaml(runLocation + "results.yaml")

# %%
import MopsDatabase
import MopsPlotter

# %%
con = sql.connect(tracker.mainDatabase)
window_dbs = MopsDatabase.attachDatabases(con, tracker.windowDatabases)

# %%
missed_objects = pd.read_sql("""SELECT objectId FROM AllObjects
                                    WHERE findableAsTrack = 1
                                    AND numTrueTracks = 0""", con)["objectId"].values
found_objects = pd.read_sql("""SELECT objectId FROM AllObjects
                                    WHERE findableAsTrack = 1
                                    AND numTrueTracks >= 1""", con)["objectId"].values
missed_objects_detections = MopsDatabase.findDetectionsWithObjectIds(con, missed_objects)
found_objects_detections = MopsDatabase.findDetectionsWithObjectIds(con, found_objects)

# %%
fig, ax = plt.subplots(1,2)
fig.set_size_inches(14,7)

ax[0].scatter(found_objects_detections["ra"], found_objects_detections["dec"], c="b", label="%s Found objects" % len(found_objects))
ax[1].scatter(missed_objects_detections["ra"], missed_objects_detections["dec"], c="r",  label="%s Missed objects" % len(missed_objects))

for a in ax:
    a.legend()
    a.set_xlabel("RA", size=16);
    a.set_ylabel("DEC", size=16);

# %%
hist, bin_edges = np.histogram(found_objects_detections["mag"].values, bins=np.linspace(12,26,15))
hist2, bins = np.histogram(missed_objects_detections["mag"].values, bins=bin_edges)
width = 0.4

fig, ax = plt.subplots(1,1)
fig.set_size_inches(10,7)
ax.bar(bin_edges[1:], hist/float(len(found_objects_detections))*100.0, width, label="Found")
ax.bar(bin_edges[1:] + width, hist2/float(len(missed_objects_detections))*100.0, width, color="r", label="Missed")
#ax.set_xticks(bin_edges[1:]);
ax.legend(loc="upper left");
ax.grid();
ax.set_title("MAG Distribution as Percent of Detections");
ax.set_xlabel("MAG");
ax.set_ylabel("% Freq");

# %%
hist, bin_edges = np.histogram(found_objects_detections["snr"].values, bins=np.linspace(0,60,20))
hist2, bins = np.histogram(missed_objects_detections["snr"].values, bins=bin_edges)
width = 0.75

fig, ax = plt.subplots(1,1)
fig.set_size_inches(10,7)
ax.bar(bin_edges[1:], hist/float(len(found_objects_detections))*100.0, width, label="Found")
ax.bar(bin_edges[1:] + width, hist2/float(len(missed_objects_detections))*100.0, width, color="r", label="Missed")
#ax.set_xticks(bin_edges[1:]);
ax.legend(loc="upper right");
ax.grid();
ax.set_title("SNR Distribution as Percent of Detections");
ax.set_xlabel("SNR");
ax.set_ylabel("% Freq");
