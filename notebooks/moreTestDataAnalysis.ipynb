# %%
import sqlite3 as sql
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import yaml

import MopsPlotter
from MopsTracker import MopsTracker
from MopsParameters import MopsParameters

% matplotlib inline

# %%
dbname = 'testData/testsources.db'

# %%
con = sql.connect(dbname)

# %%
full = pd.read_sql_query("""
SELECT * FROM testsources
""", con)

# %%
full
# Out:
#      diaid  obshistid  ssmid          ra        dec       mjd        mag  snr
# 0        0          0      1  220.643549 -21.965527  59580.16  15.181889    5
# 1        1          1      1  220.659667 -21.970416  59580.20  15.181976    5
# 2        2          2      1  221.042042 -22.085481  59581.16  15.184020    5
# 3        3          3      1  221.058056 -22.090310  59581.20  15.184099    5
# 4        4          4      1  221.437935 -22.203902  59582.16  15.185958    5
# 5        5          5      1  221.453842 -22.208670  59582.20  15.186030    5
# 6        6          6      1  221.831176 -22.320788  59583.16  15.187702    5
# 7        7          7      1  221.846974 -22.325496  59583.20  15.187766    5
# 8        8          8      1  222.221714 -22.436138  59584.16  15.189252    5
# 9        9          9      1  222.237402 -22.440785  59584.20  15.189308    5
# 10      10         10      1  222.609503 -22.549951  59585.16  15.190606    5
# 11      11         11      1  222.625078 -22.554538  59585.20  15.190654    5
# 12      12         12      1  222.994495 -22.662229  59586.16  15.191765    5
# 13      13         13      1  223.009955 -22.666755  59586.20  15.191805    5
# 14      14         14      1  223.376643 -22.772972  59587.16  15.192727    5
# 15      15         15      1  223.391988 -22.777438  59587.20  15.192759    5
# 16      16         16      1  223.755903 -22.882185  59588.16  15.193492    5
# 17      17         17      1  223.771130 -22.886591  59588.20  15.193516    5
# 18      18         18      1  224.132228 -22.989869  59589.16  15.194059    5
# 19      19         19      1  224.147334 -22.994215  59589.20  15.194075    5
# 20      20         20      1  224.505571 -23.096030  59590.16  15.194428    5
# 21      21         21      1  224.520555 -23.100316  59590.20  15.194436    5
# 22      22         22      1  224.875884 -23.200670  59591.16  15.194597    5
# 23      23         23      1  224.890745 -23.204896  59591.20  15.194597    5
# 24      24         24      1  225.243120 -23.303794  59592.16  15.194567    5
# 25      25         25      1  225.257855 -23.307960  59592.20  15.194558    5
# 26      26         26      1  225.607227 -23.405406  59593.16  15.194335    5
# 27      27         27      1  225.621834 -23.409513  59593.20  15.194319    5
# 28      28         28      1  225.968155 -23.505510  59594.16  15.193901    5
# 29      29         29      1  225.982632 -23.509558  59594.20  15.193877    5
# ..     ...        ...    ...         ...        ...       ...        ...  ...
# 150    150         30      3  299.279209 -19.257052  59595.16  24.558441    5
# 151    151         31      3  299.280414 -19.256829  59595.20  24.558336    5
# 152    152         32      3  299.309005 -19.251484  59596.16  24.556211    5
# 153    153         33      3  299.310210 -19.251261  59596.20  24.556144    5
# 154    154         34      3  299.338802 -19.245900  59597.16  24.555488    5
# 155    155         35      3  299.340008 -19.245676  59597.20  24.555506    5
# 156    156         36      3  299.368594 -19.240301  59598.16  24.556856    5
# 157    157         37      3  299.369799 -19.240076  59598.20  24.556943    5
# 158    158         38      3  299.398373 -19.234689  59599.16  24.559383    5
# 159    159         39      3  299.399577 -19.234463  59599.20  24.559498    5
# 160    160         40      3  299.428132 -19.229064  59600.16  24.562321    5
# 161    161         41      3  299.429336 -19.228838  59600.20  24.562444    5
# 162    162         42      3  299.457865 -19.223428  59601.16  24.565402    5
# 163    163         43      3  299.459068 -19.223202  59601.20  24.565528    5
# 164    164         44      3  299.487565 -19.217782  59602.16  24.568530    5
# 165    165         45      3  299.488766 -19.217556  59602.20  24.568657    5
# 166    166         46      3  299.517225 -19.212128  59603.16  24.571665    5
# 167    167         47      3  299.518424 -19.211902  59603.20  24.571792    5
# 168    168         48      3  299.546837 -19.206467  59604.16  24.574787    5
# 169    169         49      3  299.548035 -19.206240  59604.20  24.574913    5
# 170    170         50      3  299.576395 -19.200800  59605.16  24.577885    5
# 171    171         51      3  299.577590 -19.200574  59605.20  24.578010    5
# 172    172         52      3  299.605891 -19.195129  59606.16  24.580954    5
# 173    173         53      3  299.607084 -19.194903  59606.20  24.581077    5
# 174    174         54      3  299.635318 -19.189455  59607.16  24.583987    5
# 175    175         55      3  299.636507 -19.189229  59607.20  24.584109    5
# 176    176         56      3  299.664668 -19.183780  59608.16  24.586983    5
# 177    177         57      3  299.665854 -19.183553  59608.20  24.587104    5
# 178    178         58      3  299.693933 -19.178105  59609.16  24.589940    5
# 179    179         59      3  299.695116 -19.177878  59609.20  24.590059    5
#
# [180 rows x 8 columns]

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(np.array(full.ra), np.array(full.dec));
fig.savefig("full.jpg")

# %%
ssmids = pd.read_sql_query("""
SELECT DISTINCT ssmid FROM testsources
""", con)

# %%
len(ssmids['ssmid'])
# Out:
# 3

# %%
num_ssm = random.sample(ssmids['ssmid'], 1)
sample = ""
for i in num_ssm:
    sample += str(i) + ', '
    
sample = '(' + sample[0:-2] + ')'

# %%
sample = ("(1,2,3)")

# %%
objs = pd.read_sql_query("""
SELECT * FROM testsources
WHERE ssmid IN %s
""" % (sample), con)

# %%
objs
# Out:
#      diaid  obshistid  ssmid          ra        dec       mjd        mag  snr
# 0        0          0      1  220.643549 -21.965527  59580.16  15.181889    5
# 1        1          1      1  220.659667 -21.970416  59580.20  15.181976    5
# 2        2          2      1  221.042042 -22.085481  59581.16  15.184020    5
# 3        3          3      1  221.058056 -22.090310  59581.20  15.184099    5
# 4        4          4      1  221.437935 -22.203902  59582.16  15.185958    5
# 5        5          5      1  221.453842 -22.208670  59582.20  15.186030    5
# 6        6          6      1  221.831176 -22.320788  59583.16  15.187702    5
# 7        7          7      1  221.846974 -22.325496  59583.20  15.187766    5
# 8        8          8      1  222.221714 -22.436138  59584.16  15.189252    5
# 9        9          9      1  222.237402 -22.440785  59584.20  15.189308    5
# 10      10         10      1  222.609503 -22.549951  59585.16  15.190606    5
# 11      11         11      1  222.625078 -22.554538  59585.20  15.190654    5
# 12      12         12      1  222.994495 -22.662229  59586.16  15.191765    5
# 13      13         13      1  223.009955 -22.666755  59586.20  15.191805    5
# 14      14         14      1  223.376643 -22.772972  59587.16  15.192727    5
# 15      15         15      1  223.391988 -22.777438  59587.20  15.192759    5
# 16      16         16      1  223.755903 -22.882185  59588.16  15.193492    5
! python $MOPS_DIR/bin/splitByNight.py moresample.txt nightly obshist

# %%
! rm -rf run/

# %%
! python ../runMops.py nightly run
# Out:
# ------- Run MOPS -------
# Running LSST's Moving Object Pipeline
#
# ------- MOPS Parameters --------
# Current Parameter Values:
#
# ---- findTracklets ----
# 	Maximum velocity:                         0.5
# 	Minimum velocity:                         0.0
# ---- collapseTracklets ----
# 	Right Ascension tolerance:                0.002
# 	Declination tolerance:                    0.002
# 	Angular tolerance:                        5
# 	Velocity tolerance:                       0.05
# 	Method:                                   greedy
# 	Use RMS filter:                           True
# 	Maximum RMS:                              0.001
# ---- purifyTracklets ----
# 	Maximum RMS:                              0.001
# ---- removeSubsets ----
# 	Remove subsets:                           False
# 	Keep only longest:                        False
# ---- makeLinkTrackletsInput_byNight.py ----
# 	Window size:                              15
# ---- linkTracklets ----
# 	 Detection error threshold:               0.0004
# 	 Maximum right ascension acceleration:    0.02
# 	 Maximum declination acceleration:        0.02
# 	 Latest first endpoint:                   None
# 	 Earliest last endpoint:                  None
# 	 Minimum nights:                          3
# 	 Minimum detections:                      6
# 	 Output buffer size:                      1000
# 	 Maximum leaf node size:                  None
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     False
# 	idsToIndices.py:                   False
# 	collapseTracklets:                 False
# 	purifyTracklets:                   False
# 	removeSubsets                      False
# 	indicesToIds.py:                   False
# 	makeLinkTrackletsInputByNight.py:  False
# 	linkTracklets:                     False
#
# ------- Run MOPS -------
# Saving parameters to /Users/joachim/repos/neosim/unittest/run/parameters.yaml
#
# ------- Run MOPS -------
# Running findTracklets...
# Completed running findTracklets.
#
# ------- Run MOPS -------
# Running idsToIndices.py...
# Completed running idsToIndices.py.
#
# ------- Run MOPS -------
# Running collapseTracklets...
# Completed running collapseTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Running purifyTracklets...
# Completed running purifyTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Running makeLinkTrackletsInput_byNight.py...
# Completed running makeLinkTrackletsInput_byNight.py.
#
# ------- Run MOPS -------
# Running linkTracklets...
# Completed running linkTracklets.
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     True
# 	idsToIndices.py:                   True
# 	collapseTracklets:                 True
# 	purifyTracklets:                   True
# 	removeSubsets                      True
# 	indicesToIds.py:                   True
# 	makeLinkTrackletsInputByNight.py:  True
# 	linkTracklets:                     True
#
# ------- Run MOPS -------
# Saving tracker to /Users/joachim/repos/neosim/unittest/run/tracker.yaml

# %%
parameters = yaml.load(file('/Users/joachim/repos/neosim/unittest/run/parameters.yaml','r'))
tracker = yaml.load(file('/Users/joachim/repos/neosim/unittest/run/tracker.yaml','r'))

# %%
MopsPlotter.plotTracklets(objs, tracker.tracklets)

# %%
MopsPlotter.plotTracklets(objs, tracker.collapsedTrackletsById)

# %%
MopsPlotter.plotTracklets(objs, tracker.purifiedTrackletsById)

# %%
MopsPlotter.plotTracklets(objs, tracker.finalTrackletsById)

# %%
MopsPlotter.plotTracks(objs, tracker.tracks)
