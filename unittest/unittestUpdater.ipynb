# %%
import os
import random
import subprocess
import sqlite3 as sql
import pandas as pd
import shutil
 
import runMops
from MopsTracker import MopsTracker
from MopsParameters import MopsParameters

TEST_DATA_DIR = "testData/"
CONTROL_RUN_DIR = "controlRun/"
DATABASE = "testsources.db"

def updateUnittest(database, testDataDir, controlRunDir, tableName="testsources"):
    
    # Clean up any existing files in controlRunDir and testDataDir, create directoriess
    if os.path.exists(controlRunDir):
        shutil.rmtree(controlRunDir)
    os.mkdir(controlRunDir)
        
    if os.path.exists(testDataDir):
        shutil.rmtree(testDataDir)
    os.mkdir(testDataDir)
    
    # Connect to the database
    con = sql.connect(database)
    
    # Gather detections and save them to a text file
    objs = pd.read_sql_query("""
    SELECT * FROM testsources
    """, con, index_col='diaid')
    
    # Retrieve unique ssmids and limit to 3
    ssmids = objs['ssmid'].unique()
    ssmids_sample = sorted(random.sample(ssmids, 3))
    
    createTestCase(con, testDataDir, controlRunDir, "full")
    createTestCase(con, testDataDir, controlRunDir, "source1", ssmid="1")
    createTestCase(con, testDataDir, controlRunDir, "source2", ssmid="2")
    createTestCase(con, testDataDir, controlRunDir, "source3", ssmid="3")

def createTestCase(con, testDataDir, controlRunDir, subDir, ssmid=None):
    new_data_dir = os.path.join(testDataDir, subDir)
    os.mkdir(new_data_dir)
    
    nightly = os.path.join(new_data_dir, 'nightly')
    os.mkdir(nightly)
    
    if ssmid == None:
        dets = pd.read_sql_query("""
        SELECT * FROM testsources
        """, con, index_col='diaid')
        
        detsOut = os.path.join(new_data_dir, "full.txt")
        dets.to_csv(detsOut, sep=" ", header=False, index='diaid')
    else:
        dets = pd.read_sql_query("""
        SELECT * FROM testsources
        WHERE ssmid = %s
        """ % ssmid, con, index_col='diaid')
    
        detsOut = os.path.join(new_data_dir, "source%s.txt" % (ssmid))
        dets.to_csv(detsOut, sep=" ", header=False, index='diaid')

    call = ["python", os.getenv("MOPS_DIR") + "/bin/splitByNight.py", "-n", nightly, detsOut]
    subprocess.call(call);
    
    runDir = os.path.join(controlRunDir, subDir)
    parameters = MopsParameters(verbose=True)
    tracker = MopsTracker(runDir, verbose=True)
    runMops.runMops(parameters, tracker, nightly, runDir)

# %%
updateUnittest("testsources.db", "testData/", "controlRun/")
# Out:
# ------- MOPS Parameters --------
# Current Parameter Values:
#
# ---- findTracklets ----
# 	Maximum velocity:                         0.5
# 	Minimum velocity:                         0.0
# ---- collapseTracklets ----
# 	Right Ascension tolerance:                0.002
# 	Declination tolerance:                    0.002
# 	Angular tolerance:                        5
# 	Velocity tolerance:                       0.05
# 	Method:                                   greedy
# 	Use RMS filter:                           True
# 	Maximum RMS:                              0.001
# ---- purifyTracklets ----
# 	Maximum RMS:                              0.001
# ---- removeSubsets (tracklets) ----
# 	Remove subsets:                           False
# 	Keep only longest:                        False
# ---- makeLinkTrackletsInput_byNight.py ----
# 	Window size:                              15
# ---- linkTracklets ----
# 	Detection error threshold:               0.0004
# 	Maximum right ascension acceleration:    0.02
# 	Maximum declination acceleration:        0.02
# 	Latest first endpoint:                   None
# 	Earliest last endpoint:                  None
# 	Minimum nights:                          3
# 	Minimum detections:                      6
# 	Output buffer size:                      1000
# 	Maximum leaf node size:                  None
# ---- removeSubsets (tracks) ----
# 	Remove subsets:                           True
# 	Keep only longest:                        True
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     False
# 	idsToIndices.py:                   False
# 	collapseTracklets:                 False
# 	purifyTracklets:                   False
# 	removeSubsets (tracklets):         False
# 	indicesToIds.py:                   False
# 	makeLinkTrackletsInputByNight.py:  False
# 	linkTracklets:                     False
# 	removeSubsets (tracks):            False
#
# ------- Run MOPS -------
# Saving parameters to controlRun/full/parameters.yaml
#
# ------- Run MOPS -------
# Running findTracklets...
# Completed running findTracklets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/full/tracker.yaml
#
# ------- Run MOPS -------
# Running idsToIndices.py...
# Completed running idsToIndices.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/full/tracker.yaml
#
# ------- Run MOPS -------
# Running collapseTracklets...
# Completed running collapseTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/full/tracker.yaml
#
# ------- Run MOPS -------
# Running purifyTracklets...
# Completed running purifyTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/full/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/full/tracker.yaml
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/full/tracker.yaml
#
# ------- Run MOPS -------
# Running makeLinkTrackletsInput_byNight.py...
# Completed running makeLinkTrackletsInput_byNight.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/full/tracker.yaml
#
# ------- Run MOPS -------
# Running linkTracklets...
# Completed running linkTracklets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/full/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/full/tracker.yaml
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     True
# 	idsToIndices.py:                   True
# 	collapseTracklets:                 True
# 	purifyTracklets:                   True
# 	removeSubsets (tracklets):         True
# 	indicesToIds.py:                   True
# 	makeLinkTrackletsInputByNight.py:  True
# 	linkTracklets:                     True
# 	removeSubsets (tracks):            True
#
# ------- Run MOPS -------
# Saving tracker to controlRun/full/tracker.yaml
#
# ------- MOPS Parameters --------
# Current Parameter Values:
#
# ---- findTracklets ----
# 	Maximum velocity:                         0.5
# 	Minimum velocity:                         0.0
# ---- collapseTracklets ----
# 	Right Ascension tolerance:                0.002
# 	Declination tolerance:                    0.002
# 	Angular tolerance:                        5
# 	Velocity tolerance:                       0.05
# 	Method:                                   greedy
# 	Use RMS filter:                           True
# 	Maximum RMS:                              0.001
# ---- purifyTracklets ----
# 	Maximum RMS:                              0.001
# ---- removeSubsets (tracklets) ----
# 	Remove subsets:                           False
# 	Keep only longest:                        False
# ---- makeLinkTrackletsInput_byNight.py ----
# 	Window size:                              15
# ---- linkTracklets ----
# 	Detection error threshold:               0.0004
# 	Maximum right ascension acceleration:    0.02
# 	Maximum declination acceleration:        0.02
# 	Latest first endpoint:                   None
# 	Earliest last endpoint:                  None
# 	Minimum nights:                          3
# 	Minimum detections:                      6
# 	Output buffer size:                      1000
# 	Maximum leaf node size:                  None
# ---- removeSubsets (tracks) ----
# 	Remove subsets:                           True
# 	Keep only longest:                        True
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     False
# 	idsToIndices.py:                   False
# 	collapseTracklets:                 False
# 	purifyTracklets:                   False
# 	removeSubsets (tracklets):         False
# 	indicesToIds.py:                   False
# 	makeLinkTrackletsInputByNight.py:  False
# 	linkTracklets:                     False
# 	removeSubsets (tracks):            False
#
# ------- Run MOPS -------
# Saving parameters to controlRun/source1/parameters.yaml
#
# ------- Run MOPS -------
# Running findTracklets...
# Completed running findTracklets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source1/tracker.yaml
#
# ------- Run MOPS -------
# Running idsToIndices.py...
# Completed running idsToIndices.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source1/tracker.yaml
#
# ------- Run MOPS -------
# Running collapseTracklets...
# Completed running collapseTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source1/tracker.yaml
#
# ------- Run MOPS -------
# Running purifyTracklets...
# Completed running purifyTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source1/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source1/tracker.yaml
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source1/tracker.yaml
#
# ------- Run MOPS -------
# Running makeLinkTrackletsInput_byNight.py...
# Completed running makeLinkTrackletsInput_byNight.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source1/tracker.yaml
#
# ------- Run MOPS -------
# Running linkTracklets...
# Completed running linkTracklets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source1/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source1/tracker.yaml
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     True
# 	idsToIndices.py:                   True
# 	collapseTracklets:                 True
# 	purifyTracklets:                   True
# 	removeSubsets (tracklets):         True
# 	indicesToIds.py:                   True
# 	makeLinkTrackletsInputByNight.py:  True
# 	linkTracklets:                     True
# 	removeSubsets (tracks):            True
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source1/tracker.yaml
#
# ------- MOPS Parameters --------
# Current Parameter Values:
#
# ---- findTracklets ----
# 	Maximum velocity:                         0.5
# 	Minimum velocity:                         0.0
# ---- collapseTracklets ----
# 	Right Ascension tolerance:                0.002
# 	Declination tolerance:                    0.002
# 	Angular tolerance:                        5
# 	Velocity tolerance:                       0.05
# 	Method:                                   greedy
# 	Use RMS filter:                           True
# 	Maximum RMS:                              0.001
# ---- purifyTracklets ----
# 	Maximum RMS:                              0.001
# ---- removeSubsets (tracklets) ----
# 	Remove subsets:                           False
# 	Keep only longest:                        False
# ---- makeLinkTrackletsInput_byNight.py ----
# 	Window size:                              15
# ---- linkTracklets ----
# 	Detection error threshold:               0.0004
# 	Maximum right ascension acceleration:    0.02
# 	Maximum declination acceleration:        0.02
# 	Latest first endpoint:                   None
# 	Earliest last endpoint:                  None
# 	Minimum nights:                          3
# 	Minimum detections:                      6
# 	Output buffer size:                      1000
# 	Maximum leaf node size:                  None
# ---- removeSubsets (tracks) ----
# 	Remove subsets:                           True
# 	Keep only longest:                        True
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     False
# 	idsToIndices.py:                   False
# 	collapseTracklets:                 False
# 	purifyTracklets:                   False
# 	removeSubsets (tracklets):         False
# 	indicesToIds.py:                   False
# 	makeLinkTrackletsInputByNight.py:  False
# 	linkTracklets:                     False
# 	removeSubsets (tracks):            False
#
# ------- Run MOPS -------
# Saving parameters to controlRun/source2/parameters.yaml
#
# ------- Run MOPS -------
# Running findTracklets...
# Completed running findTracklets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source2/tracker.yaml
#
# ------- Run MOPS -------
# Running idsToIndices.py...
# Completed running idsToIndices.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source2/tracker.yaml
#
# ------- Run MOPS -------
# Running collapseTracklets...
# Completed running collapseTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source2/tracker.yaml
#
# ------- Run MOPS -------
# Running purifyTracklets...
# Completed running purifyTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source2/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source2/tracker.yaml
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source2/tracker.yaml
#
# ------- Run MOPS -------
# Running makeLinkTrackletsInput_byNight.py...
# Completed running makeLinkTrackletsInput_byNight.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source2/tracker.yaml
#
# ------- Run MOPS -------
# Running linkTracklets...
# Completed running linkTracklets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source2/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source2/tracker.yaml
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     True
# 	idsToIndices.py:                   True
# 	collapseTracklets:                 True
# 	purifyTracklets:                   True
# 	removeSubsets (tracklets):         True
# 	indicesToIds.py:                   True
# 	makeLinkTrackletsInputByNight.py:  True
# 	linkTracklets:                     True
# 	removeSubsets (tracks):            True
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source2/tracker.yaml
#
# ------- MOPS Parameters --------
# Current Parameter Values:
#
# ---- findTracklets ----
# 	Maximum velocity:                         0.5
# 	Minimum velocity:                         0.0
# ---- collapseTracklets ----
# 	Right Ascension tolerance:                0.002
# 	Declination tolerance:                    0.002
# 	Angular tolerance:                        5
# 	Velocity tolerance:                       0.05
# 	Method:                                   greedy
# 	Use RMS filter:                           True
# 	Maximum RMS:                              0.001
# ---- purifyTracklets ----
# 	Maximum RMS:                              0.001
# ---- removeSubsets (tracklets) ----
# 	Remove subsets:                           False
# 	Keep only longest:                        False
# ---- makeLinkTrackletsInput_byNight.py ----
# 	Window size:                              15
# ---- linkTracklets ----
# 	Detection error threshold:               0.0004
# 	Maximum right ascension acceleration:    0.02
# 	Maximum declination acceleration:        0.02
# 	Latest first endpoint:                   None
# 	Earliest last endpoint:                  None
# 	Minimum nights:                          3
# 	Minimum detections:                      6
# 	Output buffer size:                      1000
# 	Maximum leaf node size:                  None
# ---- removeSubsets (tracks) ----
# 	Remove subsets:                           True
# 	Keep only longest:                        True
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     False
# 	idsToIndices.py:                   False
# 	collapseTracklets:                 False
# 	purifyTracklets:                   False
# 	removeSubsets (tracklets):         False
# 	indicesToIds.py:                   False
# 	makeLinkTrackletsInputByNight.py:  False
# 	linkTracklets:                     False
# 	removeSubsets (tracks):            False
#
# ------- Run MOPS -------
# Saving parameters to controlRun/source3/parameters.yaml
#
# ------- Run MOPS -------
# Running findTracklets...
# Completed running findTracklets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source3/tracker.yaml
#
# ------- Run MOPS -------
# Running idsToIndices.py...
# Completed running idsToIndices.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source3/tracker.yaml
#
# ------- Run MOPS -------
# Running collapseTracklets...
# Completed running collapseTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source3/tracker.yaml
#
# ------- Run MOPS -------
# Running purifyTracklets...
# Completed running purifyTracklets.
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source3/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source3/tracker.yaml
#
# ------- Run MOPS -------
# Running indicesToIds.py...
# Completed running indicesToIds.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source3/tracker.yaml
#
# ------- Run MOPS -------
# Running makeLinkTrackletsInput_byNight.py...
# Completed running makeLinkTrackletsInput_byNight.py.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source3/tracker.yaml
#
# ------- Run MOPS -------
# Running linkTracklets...
# Completed running linkTracklets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source3/tracker.yaml
#
# ------- Run MOPS -------
# Running removeSubsets...
# Completed running removeSubsets.
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source3/tracker.yaml
#
# ------- MOPS Tracker --------
# Current run status:
#
# 	findTracklets:                     True
# 	idsToIndices.py:                   True
# 	collapseTracklets:                 True
# 	purifyTracklets:                   True
# 	removeSubsets (tracklets):         True
# 	indicesToIds.py:                   True
# 	makeLinkTrackletsInputByNight.py:  True
# 	linkTracklets:                     True
# 	removeSubsets (tracks):            True
#
# ------- Run MOPS -------
# Saving tracker to controlRun/source3/tracker.yaml
